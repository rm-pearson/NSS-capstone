# %%
import pandas as pd
import numpy as np
import re

# %%
juvenile_df = pd.read_csv('../Data/juvenile.csv', dtype = {5: str, 7: str}, header = None)

# %% [markdown]
# ## Rename Columns

# %%
juvenile_df.columns = ['UsageClass', 'CheckoutType', 'MaterialType', 'CheckoutYear', 'CheckoutMonth', 'Checkouts', 'Title', 'ISBN', 'Creator', 'Subjects', 'Publisher', 'PublicationYear']

# %% [markdown]
# ## Adjust capitalization and data types

# %%
juvenile_df['MaterialType'] = juvenile_df.MaterialType.str.title()

# %%
juvenile_df[['Title', 'TitleNotes']] = juvenile_df.Title.str.split(' / ', expand = True, n = 1)

# %%
juvenile_df['Title'] = [' '.join([w.capitalize() for w in x]) for x in juvenile_df.Title.str.split(' ')]

## Improvements To Do: capitalize first character after a (, use title case unless there's an apostrophe, keep all-caps items in all-caps?

# %%
juvenile_df['Checkouts'] = juvenile_df.Checkouts.str.replace(',', '').astype(int)

# %% [markdown]
# ## Extract Creator names in `Firstname Lastname` format

# %%
##To Do - look into juvenile_df.loc[juvenile_df.Creator.isna()]

# %%
juvenile_df['Creator'] = juvenile_df.Creator.str.strip(',')

# %%
lastnames = [re.search(r'^(.+?),', c).group(1) if str(c).find(',') != -1 else c for c in juvenile_df.Creator]

# %%
firstnames = [re.search(r'^(.+?),([A-Za-zÀ-ÿ-\'\s.]+)', c).group(2) if str(c).find(',') != -1 else '' for c in juvenile_df.Creator]

# %%
fullnames = []
i = 0

for name in lastnames:
    fullname = (str(firstnames[i]).strip() + ' ' + str(name).strip()).strip()
    fullnames.append(fullname)
    i += 1

# %%
juvenile_df['CreatorName'] = fullnames

# %% [markdown]
# ## Extract dates

# %% [markdown]
# #### Replace placeholders (`-`) with 0s, followed by `?` in incomplete years

# %%
incomplete_dates = juvenile_df.loc[(~juvenile_df.PublicationYear.isna()) & (juvenile_df.PublicationYear.str.contains('-')), 'PublicationYear'].str.extract(r'[\b\D](\d{2,3}\-{1,2})')

# %%
incomplete_dates = incomplete_dates.loc[~incomplete_dates[0].isna()]

# %%
incomplete_dates['new'] = incomplete_dates[0].str.replace('-', '0') + '?'

# %%
for i, r in incomplete_dates.iterrows():
    juvenile_df.loc[i, 'PublicationYear'] = juvenile_df.loc[i, 'PublicationYear'].replace(r[0], r['new']).replace('??', '?')

# %% [markdown]
# #### Extract different types of PublicationYear values
#
# Examples of formatting varieties (from dataset FAQ):
# * `2005` — publication date
# * `c. 2005` – copyright symbol
# * `[2005]` – Printing date
# * `p. 2005` – phonogram copyright symbol
# * `2004, c. 2005` – publication and copyright date
# * `2005-2007` – intervening years
# * `[2005?]` – Approximate date

# %%
## copyright dates
## TO DO - decide whether to use highest or lowest value when multiple are available
juvenile_df['CopyrightDate'] = juvenile_df.PublicationYear.str.findall(r'[©cC](?:&p)?\.?\s?(\d{4})')

# %%
## phonogram copyright dates
juvenile_df['PCopyrightDate'] = juvenile_df.PublicationYear.str.findall(r'\b(?:c&)?[©pP]\.?\s?(\d{4})')

# %%
## printing dates
## TO DO - account for possible spaces or periods after the copyright indicator - lookbehind assertions need to be fixed width :/
juvenile_df['PrintingDate'] = juvenile_df.PublicationYear.str.extract(r'\[.*(?<![©cCpP])(\d{4})(?!\?).*\]')

# %%
## approximate date
juvenile_df['ApproxDate'] = juvenile_df.PublicationYear.str.extract(r'\[(\d{4})\?\]')

# %% [markdown]
# for 'CreationDate', I will use the following, in order of availability:
# * publication date
# * printing date
# * copyright date
# * approximate date

# %%
##TODO: 
    ## replace empty CopyrightDate & PCopyrightDate values with nulls
    ## decide whether to keep earliest or latest copyright dates
    ## create juvenile_df.OtherDate = iff all other date columns are null, extract 4-digit from PublicationYear
    ## create juvenile_df.PublicationDate = coalesce OtherDate, PrintingDate, CopyrightDate, PCopyrightDate

# %%
juvenile_df
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0         Physical      Horizon         Book          2023             10
# 1         Physical      Horizon         Book          2023             10
# 2         Physical      Horizon         Book          2023             10
# 3         Physical      Horizon         Book          2023             10
# 4         Physical      Horizon         Book          2023             10
# ...            ...          ...          ...           ...            ...
# 6443523    Digital    OverDrive    Audiobook          2023             10
# 6443524   Physical      Horizon         Book          2023             10
# 6443525   Physical      Horizon         Book          2023             10
# 6443526    Digital    OverDrive        Ebook          2023             10
# 6443527   Physical      Horizon     Regprint          2023             10
#
#          Checkouts                                              Title  \
# 0                1                              Don't Hate The Player
# 1                1                                Thanksgiving Graces
# 2                1                                 The Elephant Thief
# 3                1                                       Elsie's Bird
# 4                6                               The Ogre In The Hall
# ...            ...                                                ...
# 6443523          1  You're A Bad Man, Mr. Gum!: Mr Gum Series, Boo...
# 6443524          5                       I Feel! : A Book Of Emotions
# 6443525          3                                 The Big Bath House
# 6443526          1                                      Pablo Picasso
# 6443527          3                                      The Sacrifice
#
#                                                       ISBN  \
# 0                 1547605022, 9781547605026, 9781547605033
# 1                                0824956346, 9780824956349
# 2                                1338188437, 9781338188431
# 3                                0399252924, 9780399252921
# 4                                1662640528, 9781662640520
# ...                                                    ...
# 6443523                                      9780061629488
# 6443524                          0358621240, 9780358621249
# 6443525  0593181956, 0593181964, 9780593181959, 9780593...
# 6443526                                      9780711286252
# 6443527                          1728255910, 9781728255910
#
#                                            Creator  \
# 0                                     Nedd, Alexis
# 1                            Moulton, Mark Kimball
# 2        Kerr, Jane (Children's literature author)
# 3                                      Yolen, Jane
# 4                                    Sorin, Céline
# ...                                            ...
# 6443523                               Andy Stanton
# 6443524                       Medina, Juana, 1980-
# 6443525                        Maclear, Kyo, 1970-
# 6443526                Maria Isabel Sanchez Vegara
# 6443527                               Chupeco, Rin
#
#                                                   Subjects  \
# 0        eSports Contests Fiction, High schools Fiction...
# 1        Stories in rhyme Juvenile fiction, Thanksgivin...
# 2        Pickpockets Juvenile fiction, Zoo keepers Juve...
# 3        Prairies Juvenile fiction, Frontier and pionee...
# 4        Monsters Juvenile fiction, Fear of the dark Ju...
# ...                                                    ...
# 6443523                                   Juvenile Fiction
# 6443524  Emotions Juvenile fiction, Emotions Fiction, P...
# 6443525  Bathhouses Juvenile fiction, Families Japan Ju...
# 6443526  Art, Biography & Autobiography, Juvenile Nonfi...
# 6443527  Blessing and cursing Juvenile fiction, Islands...
#
#                                                  Publisher PublicationYear  \
# 0                                           Bloomsbury YA,           2021.
# 1                                 Ideals Children's Books,          [2011]
# 2                          Chicken House, Scholastic Inc.,           2018.
# 3                                          Philomel Books,          [2010]
# 4        Hippo Park, an imprint of Astra Publishing House,          [2023]
# ...                                                    ...             ...
# 6443523                      HarperCollins Publishers Inc.            2008
# 6443524    Versify, an imprint of HarperCollinsPublishers,          [2022]
# 6443525                               Random House Studio,          [2021]
# 6443526                        Quarto Publishing Group USA            2023
# 6443527       Sourcebooks Fire, an imprint of Sourcebooks,          [2022]
#
#                                                 TitleNotes  \
# 0                                             Alexis Nedd.
# 1        written by Mark Kimball Moulton ; illustrated ...
# 2                                               Jane Kerr.
# 3                 Jane Yolen ; illustrated by David Small.
# 4        story by Céline Sorin ; pictures by Pascal Lam...
# ...                                                    ...
# 6443523                                               None
# 6443524                                   by Juana Medina.
# 6443525  written by Kyo Maclear ; illustrated by Gracey...
# 6443526                                               None
# 6443527                                       Rin Chupeco.
#
#                          CreatorName CopyrightDate PCopyrightDate  \
# 0                        Alexis Nedd            []             []
# 1               Mark Kimball Moulton            []             []
# 2                          Jane Kerr            []             []
# 3                         Jane Yolen            []             []
# 4                       Céline Sorin            []             []
# ...                              ...           ...            ...
# 6443523                 Andy Stanton            []             []
# 6443524                 Juana Medina            []             []
# 6443525                  Kyo Maclear            []             []
# 6443526  Maria Isabel Sanchez Vegara            []             []
# 6443527                  Rin Chupeco            []             []
#
#         PrintingDate ApproxDate
# 0                NaN        NaN
# 1               2011        NaN
# 2                NaN        NaN
# 3               2010        NaN
# 4               2023        NaN
# ...              ...        ...
# 6443523          NaN        NaN
# 6443524         2022        NaN
# 6443525         2021        NaN
# 6443526          NaN        NaN
# 6443527         2022        NaN
#
# [6443528 rows x 18 columns]
